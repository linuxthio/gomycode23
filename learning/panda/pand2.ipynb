# %%
import pandas as pd

# %%
data=pd.read_csv("../datas/Mall_Customers.csv")

# %%
data
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
age=data['Age'].value_counts()

# %%
type(age)
# Out:
# pandas.core.series.Series

# %%
len(age)
# Out:
# 51

# %%
len(dict(data))
# Out:
# 5

# %%
donne=data[['CustomerID','Age']]

# %%
donne=donne[:30]

# %%
donne
import matplotlib.pyplot as plt

# %%
donne
# Out:
#     CustomerID  Age
# 0            1   19
# 1            2   21
# 2            3   20
# 3            4   23
# 4            5   31
# 5            6   22
# 6            7   35
# 7            8   23
# 8            9   64
# 9           10   30
# 10          11   67
# 11          12   35
# 12          13   58
# 13          14   24
# 14          15   37
# 15          16   22
# 16          17   35
# 17          18   20
# 18          19   52
# 19          20   35
# 20          21   35
# 21          22   25
# 22          23   46
# 23          24   31
# 24          25   54
# 25          26   29
# 26          27   45
# 27          28   35
# 28          29   40
# 29          30   23

# %%
plt.plot(donne['CustomerID'],donne['Age'])

# %%
donne=data[['CustomerID','Age']]

# %%
p=40
plt.plot(donne['CustomerID'][:p],donne['Age'][:p])

# %%
data=data.rename(columns={'Spending Score (1-100)':'Score','Annual Income (k$)':'Annual'})

# %%
data
# Out:
#      CustomerID  Gender  Age  Annual  Score
# 0             1    Male   19      15     39
# 1             2    Male   21      15     81
# 2             3  Female   20      16      6
# 3             4  Female   23      16     77
# 4             5  Female   31      17     40
# ..          ...     ...  ...     ...    ...
# 195         196  Female   35     120     79
# 196         197  Female   45     126     28
# 197         198    Male   32     126     74
# 198         199    Male   32     137     18
# 199         200    Male   30     137     83
#
# [200 rows x 5 columns]

# %%
data.shape
# Out:
# (200, 5)

# %%
data.plot()
# Out:
# <Axes: >

# %%
===
