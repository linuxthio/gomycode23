# %%
import pandas as pd

# %%
uu="https://fr.wikipedia.org/wiki/Population_mondiale"
data=pd.read_html(uu)

# %%
i=0
for d in data:
    print(f'...............................  ............{i}...................................................')
    print(d)
    i+=1
# Out:
# ...............................  ............0...................................................
#                                 Région        2022 (%)        2030 (%)  \
# 0                Afrique subsaharienne  1 152 (14,5 %)  1 401 (16,5 %)
# 1  Afrique du Nord et Asie occidentale     549 (6,9 %)     617 (7,2 %)
# 2         Asie centrale et Asie du Sud  2 075 (26,1 %)  2 248 (26,4 %)
# 3     Asie de l'Est et Asie du Sud-Est  2 342 (29,5 %)  2 372 (27,9 %)
# 4           Europe et Amérique du Nord  1 120 (14,1 %)  1 129 (13,3 %)
# 5          Amérique latine et Caraïbes     658 (8,3 %)     695 (8,2 %)
# 6        Australie et Nouvelle-Zélande      31 (0,4 %)      34 (0,4 %)
# 7                Autres pays d'Océanie      14 (0,2 %)      15 (0,2 %)
# 8                                Monde           7 942           8 512
#
#          2050 (%)
# 0  2 094 (21,6 %)
# 1       771 (8 %)
# 2  2 575 (26,6 %)
# 3  2 317 (23,9 %)
# 4  1 125 (11,6 %)
# 5     749 (7,7 %)
# 6      38 (0,4 %)
# ...

# %%
data[9]
# Out:
#     v · mRéchauffement climatique et énergie  \
# 0                   Réchauffement climatique
# 1                    Actions internationales
# 2                             Effet de serre
# 3                                    Énergie
# 4                   Énergie non renouvelable
# 5   Énergie renouvelable (électricité - gaz)
# 6                        Vecteur énergétique
# 7                                   Stockage
# 8                        Économies d'énergie
# 9                                    Société
# 10                              Anthropocène
#
#            v · mRéchauffement climatique et énergie.1
# 0   Climat Histoire du climat Graphique en crosse ...
# 1   Sommet de la Terre Convention-cadre des Nation...
# 2   Albédo Bilan radiatif de la Terre Rayonnement ...
# 3   Agence internationale de l'énergie Agence inte...
# 4   Charbon Gaz Pic gazier Nucléaire Pétrole Pic p...
# 5   Biogaz Biomasse Déchets Éolienne Géothermie Hy...
# ...
