# %%
import pandas as pd

# %%
u="https://fr.wikipedia.org/wiki/Tableau_p%C3%A9riodique_des_%C3%A9l%C3%A9ments"
data=pd.read_html(u)

# %%
type(data[2])
# Out:
# pandas.core.frame.DataFrame

# %%
len(data)
# Out:
# 22

# %%
i=0
for e in data:
    print(f'..................................{i}...........................>>>>>...')
    i+=1
    print(e)
# Out:
# ..................................0...........................>>>>>...
#              0            1            2    3       4       5       6   \
# 0           CAS          I A         II A  NaN   III B    IV B     V B
# 1         IUPAC          I A         II A  NaN   III A    IV A     V A
# 2           NaN       Bloc s       Bloc s    f  Bloc d  Bloc d  Bloc d
# 3            ↓→            1            2  NaN    3[b]       4       5
# 4             1          1 H          NaN  NaN     NaN     NaN     NaN
# 5             2         3 Li         4 Be  NaN     NaN     NaN     NaN
# 6             3        11 Na        12 Mg  NaN     NaN     NaN     NaN
# 7             4         19 K        20 Ca  NaN   21 Sc   22 Ti    23 V
# 8             5        37 Rb        38 Sr  NaN    39 Y   40 Zr   41 Nb
# 9             6        55 Cs        56 Ba    *   71 Lu   72 Hf   73 Ta
# 10            7        87 Fr        88 Ra  * *  103 Lr  104 Rf  105 Db
# ...
