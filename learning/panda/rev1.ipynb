# %%
import pandas as pd

# %%
data=pd.read_csv('../datas/titanic.csv')

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data2=data.drop(['Pclass','Embarked','SibSp','Ticket','Fare','Parch','Cabin','Name','PassengerId'],axis=1)

# %%
data2[data2['Sex']=='male'].plot()
# Out:
# <Axes: >

# %%
data3=data2.dropna()

# %%
data3[data3['Age']>30].plot.bar()
# Out:
# <Axes: >

# %%
data3.iloc[2]
# Out:
# Survived         1
# Sex         female
# Age           26.0
# Name: 2, dtype: object

# %%
data3['Sex'].iloc[2]
# Out:
# 'female'
