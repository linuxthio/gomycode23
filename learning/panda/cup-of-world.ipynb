# %%
import pandas as pd

# %%
url="https://fr.wikipedia.org/wiki/Coupe_du_monde_de_football"
data=pd.read_html(url)

# %%
data[2]
# Out:
#    Édition  Année                 Vainqueur        Score  \
# 0      1re   1930               Uruguay (1)        4 - 2
# 1       2e   1934                Italie (1)   2 - 1 (ap)
# 2       3e   1938                Italie (2)        4 - 2
# 3       4e   1950               Uruguay (2)     2 - 1[f]
# 4       5e   1954  Allemagne de l'Ouest (1)        3 - 2
# 5       6e   1958                Brésil (1)        5 - 2
# 6       7e   1962                Brésil (2)        3 - 1
# 7       8e   1966            Angleterre (1)   4 - 2 (ap)
# 8       9e   1970                Brésil (3)        4 - 1
# 9      10e   1974  Allemagne de l'Ouest (2)        2 - 1
# 10     11e   1978             Argentine (1)   3 - 1 (ap)
# 11     12e   1982                Italie (3)        3 - 1
# 12     13e   1986             Argentine (2)        3 - 2
# 13     14e   1990  Allemagne de l'Ouest (3)        1 - 0
# 14     15e   1994                Brésil (4)  0 - 0 (3-2)
# ...
