# %%
import pandas as pd

# %%
u="https://scikit-learn.org/stable/install.html"
data=pd.read_html(u)

# %%
data=data[0]

# %%
data.describe()
# Out:
#        Dependency Minimum Version Purpose
# count          26              26      26
# unique         26              24      11
# top         numpy           2.0.0   tests
# freq            1               2       6

# %%
data
# Out:
#              Dependency Minimum Version                           Purpose
# 0                 numpy          1.17.3                    build, install
# 1                 scipy           1.5.0                    build, install
# 2                joblib           1.1.1                           install
# 3         threadpoolctl           2.0.0                           install
# 4                cython         0.29.33                             build
# 5            matplotlib           3.1.3  benchmark, docs, examples, tests
# 6          scikit-image          0.16.2             docs, examples, tests
# 7                pandas           1.0.5  benchmark, docs, examples, tests
# 8               seaborn           0.9.0                    docs, examples
# 9       memory_profiler          0.57.0                   benchmark, docs
# 10               pytest           7.1.2                             tests
# 11           pytest-cov           2.9.0                             tests
# ...
